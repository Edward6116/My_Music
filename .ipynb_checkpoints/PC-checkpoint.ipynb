# %%
def Hunter():
    import time
    global PC_HP
    global NPC_HP
    global hide
    global hide_reset
    global turns
    global fell
    global damage
    Hunter_Hit = (random.randint(1,10))
    if hide_reset > 0:
        hide_reset -=1
    else:
        hide = 0
    if fell == 1:
        print "Your knocked down, You take the turn getting up."
    else:
        print "Your abilities are:\n hide(1) - take no damage for 3 turns\n arrow(2) - 5 damage(x3 damage when hidden)"
        Act_H = raw_input("It's your turn. What is your action Hunter?\n")
        if Act_H == '1':
            if hide_reset <= 0:
                hide = 1
                hide_reset = 2
                print "You are now hidden."
            else:
                hide = 0
                hide_reset = 5
                print "You must now wait 5 turns until you can hide. FIGHT COWARD!"
        elif Act_H == '2':
            if Hunter_Hit <= 9:
                if hide > 0:
                    NPC_HP -= 15
                else:
                    NPC_HP -= 5
            else:
                print "Hit or miss. I guess you're gonna miss."
        else:
            Hunter()
    if hide > 0:
        print "Your opponent couldn't find you because of how hidden you were."
    else:
        print "Your opponent is fighting back, show them no mercy!"
        Damage()
        PC_HP -= damage
    if NPC_HP <= 0:
        print "You defeated your opponent in " + str(turns) + " turns!"
    elif PC_HP <= 0:
        print "You were defeated. Resetting simulation."
        time.sleep(3)
        Brawl()
    else:
        print "Your current health is " + str(PC_HP) + ". Your opponent's health is " + str(NPC_HP) + "."
        turns += 1
        time.sleep(1)
        Hunter()

# %%
def Mage():
    import time
    global PC_HP
    global NPC_HP
    global shield
    global sheild_reset
    global burn
    global burn_timer
    global heal_timer
    global turns
    global fell
    global damage
    Mage_Hit = (random.randint(1,10))
    if shield_reset > 0:
        shield_reset -=1
        PC_HP += 5
    else:
        shield = 0
    if burn_timer > 0:
        burn_timer -=1
        NPC_HP -= 5
    else:
        burn = 0
    if fell == 1:
        print "Your knocked down, You take the turn getting up."
    else:
        print "Your abilities are:\n Magic Shield(1) - take 5 less damage for 5 turns\n Fire Bolt(2) - 10 damage and burns 5 damage for 2 turns\n Healing Breath(3) - You heal 15 damage over 3 turns"
        Act_M = raw_input("It's your turn. What is your action Mage?\n")
        if Act_M == '1':
            shield = 1
            shield_reset = 5
            print "You are now shielded."
        elif Act_M == '2':
            if Mage_Hit == 8:
                NPC_HP -= 10
                burn = 1
                burn_timer = 2
            else:
                print "You missed your attack. Better luck next time."
        elif Act_M == '3':
            heal_timer = 3
        else:
            Mage()
    print "Your opponent is fighting back, show them no mercy!"
    Damage()
    if shield == 1:
        damage -= 5
        PC_HP -= damage
    else:
        PC_HP -= damage
    if heal_timer > 0:
        heal_timer -= 1
        PC_HP += 5
    else:
        heal_timer = 0
    if NPC_HP <= 0:
        print "You defeated your opponent in " + str(turns) + " turns!"
    elif PC_HP <= 0:
        print "You were defeated. Resetting simulation."
        time.sleep(3)
        Brawl()
    else:
        print "Your current health is " + str(PC_HP) + ". Your opponent's health is " + str(NPC_HP) + "."
        turns += 1
        time.sleep(1)
        Mage()

# %%
def Goblin():
    import time
    global PC_HP
    global NPC_HP
    global shield
    global gobs
    global marked
    global braved
    global turns
    global fell
    global damage
    print "You have " + str(gobs) + " Goblin allies."
    Goblin_Hit = (random.randint(1,10))
    if fell == 1:
        print "Your knocked down, You take the turn getting up."
    else:
        print "Your abilities are:\n Rally(1) - Call 4 goblins in to help you, The goblins can attack and take hits\n Ambush(2) - You shank your oppenent for 3 damage times the number of ally goblins\n Bounty(3) - If you hit your next Ambush with two or more goblins your next Rally 5 times your current number of Goblins"
        Act_G = raw_input("It's your turn. What is your action Kranko?\n")
        if Act_G == '1':
            if braved == 1:
                gobs *= 5
                braved = 0
            else:
                gobs += 4
            print "You have " + str(gobs) + " Goblin allies."
        elif Act_G == '2':
            if Goblin_Hit <= 6
                if marked == 1:
                    if gobs >= 2:
                        braved = 1
                        NPC_HP -= 3 * gobs
                        marked = 0
                    else:
                        NPC_HP -= 3 * gobs
                        marked = 0
                else:
                    NPC_HP -= 3 * gobs
            else:
                print "Your attack missed. Shank em' next turn."
        elif Act_G == '3':
            marked = 1
        else:
            Goblin()
    print "Your opponent is fighting back, show them no mercy!"
    Damage()
    if gobs > 1:
        damage = 0
        gobs -= 2
    else:
        gobs = 1
        PC_HP -= damage
    if NPC_HP <= 0:
        print "You defeated your opponent in " + str(turns) + " turns!"
    elif PC_HP <= 0:
        print "You were defeated. Resetting simulation."
        time.sleep(3)
        Brawl()
    else:
        print "Your current health is " + str(PC_HP) + ". Your opponent's health is " + str(NPC_HP) + "."
        turns += 1
        time.sleep(1)
        Goblin()

# %%
def Knight():
    import time
    global PC_HP
    global NPC_HP
    global defend
    global stun
    global turns
    global fell
    global damage
    Knight_Hit = (random.randint(1,10))
    if fell == 1:
        print "Your knocked down, You take the turn getting up."
    else:
        print "Your abilities are:\n Defence(1) - You take 10 less damage until you attack\n Quick Breath(2) - You heal 25 heath\n Swift Slash(3) - Deals 10 damage, but deals 25 when coming out of a shield\n Charge(4) - You charge shielding yourself dealing 5 and stuns the enemey"
        Act_K = raw_input("It's your turn. What is your action Knight?\n")
        if Act_K == '1':
            defend = 1
        elif Act_K == '2':
            PC_HP += 25
        elif Act_K == '3':
            if defend == 1:
                if Kight_Hit <= 7:
                    NPC_HP -= 25
                    defend = 0
                else:
                    print "Don't worry Sir Kite. Just try again"
            else:
                NPC_HP -= 10
        elif Act_K == '4':
            if Knight_Hit <= 8:
                NPC_HP -= 5
                defend = 1
                stun = 2
            else:
                print "Just charge again. What could go wrong?"
        else:
            Knght()
    print "Your opponent is fighting back, show them no mercy!"
    Damage()
    if defend == 1:
        PC_HP -= damage - 10
        fell = 0
    elif stun > 0:
        print "Your opponent is stunned"
        stun -= 1
        fell = 0
    else:
        PC_HP -= damage
    if NPC_HP <= 0:
        print "You defeated your opponent in " + str(turns) + " turns!"
    elif PC_HP <= 0:
        print "You were defeated. Resetting simulation."
        time.sleep(3)
        Brawl()
    else:
        print "Your current health is " + str(PC_HP) + ". Your opponent's health is " + str(NPC_HP) + "."
        turns += 1
        time.sleep(1)
        Knight()

# %%
def Beast():
        import time
    global PC_HP
    global NPC_HP
    global 
    global turns
    global fell
    global damage
    if fell == 1:
        print "Your knocked down, You take the turn getting up."
    else:
        print "Your abilities are:\n Roar(1) - You scare your oppenent for 3 turns and have a 10% chance to make them run away\n Slam(2) - You deal 10 damage\n Rage(3) - Your hit chance is 100%(Roar does not apply), but take 5 extra damage for 2 turns\n Chuck(4) - "
        Act_B = raw_input("It's your turn. What is your action Beast?\n")
        if Act_B == '1':
            defend = 1
        elif Act_B == '2':
            PC_HP += 25
        elif Act_B == '3':
            if defend == 1:
                NPC_HP -= 25
                defend = 0
            else:
                NPC_HP -= 10
        elif Act_B == '4';
            NPC_HP -= 5
            defend = 1
            stun = 2
        else:
            Beast()
    print "Your opponent is fighting back, show them no mercy!"
    Damage()
    if defend == 1:
        PC_HP -= damage - 10
        fell = 0
    elif stun > 0:
        print "Your opponent is stunned"
        stun -= 1
        fell = 0
    else:
        PC_HP -= damage
    if NPC_HP <= 0:
        print "You defeated your opponent in " + str(turns) + " turns!"
    elif PC_HP <= 0:
        print "You were defeated. Resetting simulation."
        time.sleep(3)
        Brawl()
    else:
        print "Your current health is " + str(PC_HP) + ". Your opponent's health is " + str(NPC_HP) + "."
        turns += 1
        time.sleep(1)
        Beast()
